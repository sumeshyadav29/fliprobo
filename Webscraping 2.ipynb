# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("data analyst")

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
loc=[]
exp_req=[]
comp_name=[]

title_tags=driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    job_title.append(i.text)

    
loc_tags=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tags[0:10]:
    loc.append(i.text)

exp_tags=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp_tags[0:10]:
    exp_req.append(i.text)

c_tags=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in c_tags[0:10]:
    comp_name.append(i.text)

# %%
df_da=pd.DataFrame({"JOB TITLE":job_title,"Location":loc,"Experince required":exp_req,"Company name":comp_name,})
df_da
# Out:
#                                 JOB TITLE                            Location  \
# 0               Sr Data Analyst - Tableau                 Bangalore/Bengaluru
# 1  Data Analyst / 4 - 7 years / Bangalore                 Bangalore/Bengaluru
# 2          Data Analyst, Business Analyst  Bangalore/Bengaluru(HSR Layout +1)
# 3                         Sr Data Analyst                 Bangalore/Bengaluru
# 4                         Sr Data Analyst                 Bangalore/Bengaluru
# 5                     Senior Data Analyst                 Bangalore/Bengaluru
# 6                            Data Analyst     Temp. WFH - Bangalore/Bengaluru
# 7                  Financial Data Analyst                 Bangalore/Bengaluru
# 8                            Data Analyst                 Bangalore/Bengaluru
# 9                            Data Analyst                 Bangalore/Bengaluru
#
#   Experince required                        Company name
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("data scientist")

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
title=[]
location=[]
c_name=[]

title_tags=driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title.append(i.text)

    
loc_tags=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tags[0:10]:
    location.append(i.text)


c_tags=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in c_tags[0:10]:
    c_name.append(i.text)

# %%
df_ds=pd.DataFrame({"JOB TITLE":job_title,"Location":loc,"Company name":comp_name,})
df_ds
# Out:
#                                 JOB TITLE                            Location  \
# 0               Sr Data Analyst - Tableau                 Bangalore/Bengaluru
# 1  Data Analyst / 4 - 7 years / Bangalore                 Bangalore/Bengaluru
# 2          Data Analyst, Business Analyst  Bangalore/Bengaluru(HSR Layout +1)
# 3                         Sr Data Analyst                 Bangalore/Bengaluru
# 4                         Sr Data Analyst                 Bangalore/Bengaluru
# 5                     Senior Data Analyst                 Bangalore/Bengaluru
# 6                            Data Analyst     Temp. WFH - Bangalore/Bengaluru
# 7                  Financial Data Analyst                 Bangalore/Bengaluru
# 8                            Data Analyst                 Bangalore/Bengaluru
# 9                            Data Analyst                 Bangalore/Bengaluru
#
#                          Company name
# 0           S.A.W IT Services Pvt Ltd
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below
#     You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("data scientist")


search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
filter_location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[4]/label/i")
filter_location.click()

# %%
filter_salary=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i")
filter_salary.click()

# %%
job_title=[]
loc=[]
exp_req=[]
comp_name=[]

title_tags=driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    job_title.append(i.text)

    
loc_tags=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tags[0:10]:
    loc.append(i.text)

exp_tags=driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp_tags[0:10]:
    exp_req.append(i.text)

c_tags=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in c_tags[0:10]:
    comp_name.append(i.text)

# %%
df_da_f=pd.DataFrame({"JOB TITLE":job_title,"Location":loc,"Experince required":exp_req,"Company name":comp_name,})
df_da_f
# Out:
#                                            JOB TITLE  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2                 Data Science - Engineering Manager
# 3                                     Data Scientist
# 4                               Analyst-Data Science
# 5                           Principal Data Scientist
# 6                  Data Scientist - R / Python / SQL
# 7  ACN - Applied Intelligence - Data & Insights -...
# 8                                     Data Scientist
# 9                  Sr Data Scientist | Gurgaon | WFO
#
#                                             Location Experince required  \
# 0  Delhi / NCR, New Delhi, Hyderabad/Secunderabad...            4-8 Yrs
# 1  Hybrid - Noida, Kolkata, Hyderabad/Secunderaba...           5-10 Yrs
# 2                     New Delhi, Bangalore/Bengaluru            3-5 Yrs
# 3                                     Hybrid - Noida            4-9 Yrs
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
#
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.flipkart.com/")

# as a login window pops up when website opens. To close that:
close=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
close.click()

# %%
designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys("sunglasses")


search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
title=[]
brand=[]
price=[]
discount=[]


for page in range(0,3):

    title_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in title_tags:
        title.append(i.text)


    brand_tags=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand_tags:
        brand.append(i.text)

    price_tags=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for i in price_tags:
        price.append(i.text)

    discount_tags=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
    for i in discount_tags:
        discount.append(i.text)
    
    next_button=driver.find_element(By.XPATH, '//a[@class="_1LKTO3" and span="Next"]')
    next_button.click()
    time.sleep(1)

# %%
df_flipkart=pd.DataFrame({"Title":title[:99],"Brand":brand[:99],"Price":price[:99],"Discount":discount[:99],})
df_flipkart
# Out:
#                                                 Title          Brand Price  \
# 0   by Lenskart Polarized, UV Protection Rectangul...  VINCENT CHASE  ₹849
# 1            UV Protection Clubmaster Sunglasses (53)   Silver Kartz  ₹278
# 2   Riding Glasses, Night Vision Spectacle Sunglas...     LIZA ANGEL  ₹129
# 3    UV Protection Rectangular Sunglasses (Free Size)       Fastrack  ₹489
# 4          UV Protection Retro Square Sunglasses (53)     PHENOMENAL  ₹129
# ..                                                ...            ...   ...
# 94          UV Protection Oval Sunglasses (Free Size)      New Specs  ₹199
# 95       UV Protection Cat-eye Sunglasses (Free Size)         SUNBEE  ₹149
# 96           UV Protection Over-sized Sunglasses (62)      ROYAL SON  ₹699
# 97  Polarized, UV Protection Retro Square Sunglass...      ROYAL SON  ₹854
# 98    UV Protection Aviator, Wayfarer Sunglasses (54)      Elligator  ₹149
#
#    Discount
# 0   57% off
# 1   81% off
# 2   87% off
# 3   38% off
# ...

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product- reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
#             As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
rating=[]
RS=[]
FR=[]

while len(rating) < 101:

    rating_tags=driver.find_elements(By.XPATH, '//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tags:
        rating.append(i.text)


    RS_tags=driver.find_elements(By.XPATH, '//p[@class="_2-N8zT"]')
    for i in RS_tags:
        RS.append(i.text)
        

    FR_tags=driver.find_elements(By.XPATH, '//div[@class="t-ZTKy"]')
    for i in FR_tags:
        FR.append(i.text)
        

    
    next_button=driver.find_element(By.XPATH, '//a[@class="_1LKTO3" and span="Next"]')
    next_button.click()
    time.sleep(1)

# %%
df_review=pd.DataFrame({"Rating":rating[:99],"Review Summary":RS[:99],"Full Review":FR[:99]})
df_review
# Out:
#    Rating     Review Summary  \
# 0       4    Value-for-money
# 1       5  Worth every penny
# 2       5   Perfect product!
# 3       5           Terrific
# 4       5     Simply awesome
# ..    ...                ...
# 94      5            Awesome
# 95      5       Does the job
# 96      5             Super!
# 97      5          Brilliant
# 98      5          Must buy!
#
#                                           Full Review
# 0   Just got this iphone 11\nAnd it is most powerf...
# 1   Smooth like butter, camera like fantabulous, s...
# 2   Iphone is just awesome.. battery backup is ver...
# 3   Really worth of money. i just love it. It is t...
# 4   Excellent camera, good performance, no lag. Th...
# ..                                                ...
# 94  Always love the apple products, upgraded from ...
# 95  phone is good but in display is 720p lcd in th...
# 96  This is my first ever iPhone.\nAnd I truly don...
# 97  A wort full value for money decision it’s . Si...
# ...

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.flipkart.com/")

# as a login window pops up when website opens. To close that:
close=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
close.click()

# %%
designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys("Sneakers")


search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
title=[]
brand=[]
price=[]


for page in range(0,3):

    title_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in title_tags:
        title.append(i.text)


    brand_tags=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand_tags:
        brand.append(i.text)

    price_tags=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for i in price_tags:
        price.append(i.text)


    
    next_button=driver.find_element(By.XPATH, '//a[@class="_1LKTO3" and span="Next"]')
    next_button.click()
    time.sleep(1)

# %%
df_sneaker=pd.DataFrame({"Brand":brand[:99],"Product Description":title[:99],"Price":price[:99]})
df_sneaker
# Out:
#             Brand                                Product Description   Price
# 0           Krors  Women's Breathable Sneakers Running Shoes Fitn...    ₹599
# 1   RODDICK SHOES  Fashion Outdoor Canvas Casual Light Weight Lac...    ₹479
# 2          Labbin                                   Sneakers For Men    ₹399
# 3          Shozie                                   Sneakers For Men    ₹295
# 4          Kzaara                                   Sneakers For Men    ₹229
# ..            ...                                                ...     ...
# 94         BRUTON                           CLARKIN Sneakers For Men    ₹299
# 95         Reevas  Men's Combo Pack of 02 Shoes for Men Casual Sh...    ₹649
# 96  WHITE WALKERS                                   Sneakers For Men    ₹599
# 97       RED TAPE                                   Sneakers For Men  ₹1,039
# 98         DUCATI  Comfy Mid-Top Casual Chunky Streetwear Fashion...  ₹1,529
#
# [99 rows x 3 columns]

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#
#     After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver=webdriver.Chrome(r"C:\Users\sumesh\OneDrive\Desktop\chromedriver.exe")
driver.get("https://www.amazon.in/")

# %%
designation=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
designation.send_keys("Laptop")


search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
title=[]
rating=[]
price=[]

title_tags=driver.find_elements(By.XPATH, '//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tags:
    title.append(i.text)


rating_tags=driver.find_elements(By.XPATH, '//div[@class="a-section a-spacing-small a-spacing-top-small"]//span[@class="a-size-base"]')
for i in rating_tags:
    rating.append(i.text)

price_tags=driver.find_elements(By.XPATH, '//div[@class="a-section a-spacing-none a-spacing-top-micro s-price-instructions-style"] //span[@class="a-price-whole"]')
for i in price_tags:
    price.append(i.text)

# %%
len(price)
# Out:
# 22

# %%
df_laptop=pd.DataFrame({"TITLE":title[:10],"Rating":rating[:10],"Price":price[:10]})
df_laptop
# Out:
#                                                TITLE Rating   Price
# 0  Lenovo IdeaPad 3 11th Gen Intel Core i3 15.6" ...  (4.1)  37,328
# 1  Acer Extensa Intel Core i3 11th Gen Intel Core...  (3.0)  30,990
# 2  (Renewed) Dell Latitude E5470 Intel Core i5 6t...  (3.6)  19,289
# 3  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...  (3.9)  25,990
# 4  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...  (3.7)  26,699
# 5  HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6i...  (3.7)  28,990
# 6  HP 15s, AMD Athlon Silver 3050U 8GB RAM/512GB ...  (3.8)  29,399
# 7  Lenovo V15 Intel Celeron N4020 15.6" (39.62 cm...  (3.8)  19,990
# 8  AVITA SATUS ULTIMUS S111 NU14A1INC43PN-SG 14.1...  (3.3)  16,990
# 9  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...  (4.1)  29,230

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.azquotes.com/")

# %%
top_quote=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
top_quote.click()

# %%
quote=[]
author=[]
types=[]


while len(quote)<901:

    quote_tags=driver.find_elements(By.XPATH, '//a[@class="title"]')
    for i in quote_tags:
        quote.append(i.text)

    author_tags=driver.find_elements(By.XPATH, '//div[@class="author"]')
    for i in author_tags:
        author.append(i.text)

    type_tags=driver.find_elements(By.XPATH, '//div[@class="tags"]')
    for i in type_tags:
        types.append(i.text)

    if len(quote)==1000:
        break 
    else :
        next_button=driver.find_element(By.XPATH, '//li[@class="next"]')
        next_button.click()
        time.sleep(1)

# %%
df_quotes=pd.DataFrame({"Quote":quote,"author":author,"Type of Quote":types})
df_quotes
# Out:
#                                                  Quote              author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                 Type of Quote
# ...

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpage https://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make the DataFrame.

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.jagranjosh.com/")

# %%
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a")
gk.click()

# %%
pm_list=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
pm_list.click()

# %%
Name=[]
Born_Dead=[]
Term=[]
Remarks=[]
alls=[]
list_tags=driver.find_elements(By.TAG_NAME,"tr")
for i in list_tags[1:19]:
    alls.append(i.text)
    Name.append(i.text.split("\n")[1])
    Born_Dead.append(i.text.split("\n")[2])
    Term.append(i.text.split("\n")[3])
#due to some error,last index of remarks could not be scraped. So did that separately.
for i in list_tags[1:18]:    
    Remarks.append(i.text.split("\n")[5])

Remarks.append(driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[19]/td[5]/p').text)

# %%
df_pm=pd.DataFrame({"Name":Name,"Born-Dead":Born_Dead,"Term of Office":Term,"Remarks":Remarks})
df_pm
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                          Term of Office  \
# ...

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name ,Description and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on left side.
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.motor1.com/")

# %%
hamb=driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/div/div[1]/div")
hamb.click()

# %%
features=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[5]/button")
features.click()

# %%
list1=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a")
list1.click()

# %%
list50=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[2]/div/div[1]/h3/a")
list50.click()

# %%
name=[]
desc=[]
price=[]
name_tags=driver.find_elements(By.XPATH, '//h3[@class="subheader"]')
for i in name_tags[0:50]:
    name.append(i.text)

price_tags=driver.find_elements(By.TAG_NAME,"strong")
for i in price_tags:
    price.append(i.text)

price.remove("")
    

x = range(5,105,2)
w=[]
desc_tags=driver.find_elements(By.TAG_NAME,"p")
for i in desc_tags:
    w.append(i.text)
for n in x:
    desc.append(w[n])

# %%
df_cars=pd.DataFrame({"Name":name,"Description":desc,"price":price})
df_cars
# Out:
#                                Name  \
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# ...
